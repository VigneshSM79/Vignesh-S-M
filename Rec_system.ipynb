# %%
import pandas as pd

# %%
data = pd.read_csv("C:\ML\AOD_Rec_system\source.csv")

# %%
data.head(25)
# Out:
#                                    RQID                       USERID  \
# 0      CD937F21EA5248A9A1C5E2322C5ED481      seth.schwartz@effem.com
# 1      CD937F21EA5248A9A1C5E2322C5ED481      seth.schwartz@effem.com
# 2      CD937F21EA5248A9A1C5E2322C5ED481      seth.schwartz@effem.com
# 3      CD937F21EA5248A9A1C5E2322C5ED481      seth.schwartz@effem.com
# 4      CD937F21EA5248A9A1C5E2322C5ED481      seth.schwartz@effem.com
# 5      CD937F21EA5248A9A1C5E2322C5ED481      seth.schwartz@effem.com
# 6      CD937F21EA5248A9A1C5E2322C5ED481      seth.schwartz@effem.com
# 7      CD937F21EA5248A9A1C5E2322C5ED481      seth.schwartz@effem.com
# 8      CD937F21EA5248A9A1C5E2322C5ED481      seth.schwartz@effem.com
# 9      CD937F21EA5248A9A1C5E2322C5ED481      seth.schwartz@effem.com
# 10     CD937F21EA5248A9A1C5E2322C5ED481      seth.schwartz@effem.com
# 11  OI_09CAFA4E24474D62829600D2AF0011EE  avinash.naik.ap@nielsen.com
# 12  OI_09CAFA4E24474D62829600D2AF0011EE  avinash.naik.ap@nielsen.com
# ...

# %%
val = (data.groupby(by=["RQID","Dimension","Path"])["Values"].size()).reset_index()

# %%
val.head()
# Out:
#                                RQID Dimension  \
# 0  0013B6D1F17E48CF9C976879C6AAC0FF     Facts
# 1  0013B6D1F17E48CF9C976879C6AAC0FF     Facts
# 2  0013B6D1F17E48CF9C976879C6AAC0FF   Markets
# 3  0013B6D1F17E48CF9C976879C6AAC0FF   Periods
# 4  0013B6D1F17E48CF9C976879C6AAC0FF   Periods
#
#                                                 Path  Values
# 0     Groups (Folders)|MARS Fact Groups^Sales Volume       1
# 1  Groups (folders)|MARS CNF Fact Group^Distribution       2
# 2      Groups (folders)|Market Groups^Mass Retailers       1
# 3  Groups (folders)|Mars Custom Period Groups^4 W...       1
# 4  Groups (folders)|Mars Custom Period Groups^Cur...       1

# %%
val_count = val[val['Values']>5]

# %%
val_count.head()
# Out:
#                                 RQID Dimension  \
# 22  002120F51969417888A3E0195F33C2FF     Facts
# 24  002120F51969417888A3E0195F33C2FF     Facts
# 25  002120F51969417888A3E0195F33C2FF     Facts
# 27  002120F51969417888A3E0195F33C2FF   Periods
# 31  002B64F2FF6145AEAE261EAAFE7A75E9     Facts
#
#                                                  Path  Values
# 22  Groups (folders)|MARS CNF Fact Group^Display C...       8
# 24  Groups (folders)|MARS CNF Fact Group^Promotion...      20
# 25  Groups (folders)|MARS CNF Fact Group^Sales Volume       7
# 27   Groups (folders)|Mars Custom Period Groups^Weeks      26
# 31  Groups (Folders)|MARS CNF Fact Group^Promotion...       8

# %%
dfb = val_count.index.values.astype(int)[:5]

# %%
dfb[:7]
# Out:
# array([22, 24, 25, 27, 31, 32, 33])

# %%
#test
val_count['val_desc'] = data['Values'].loc[[(val_count.index.values.astype(int)[:5])]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-573c1cba6f80> in <module>
#       1 #test
# ----> 2 val_count['val_desc'] = data['Values'].loc[[(val_count.index.values.astype(int)[:5])]]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1900                     raise ValueError('Cannot index with multidimensional key')
#    1901
# -> 1902                 return self._getitem_iterable(key, axis=axis)
#    1903
#    1904             # nested tuple slicing
#
# ...

# %%
#df.iloc[[2]]
for i in dfb:
    print(i)
    val_count['val_desc'] = data['Values'].iloc[[i]]
# Out:
# 22
# C:\Users\VICKY\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# 24
# 25
# 27
# 31

# %%
val_count
# Out:
#                                       RQID Dimension  \
# 22        002120F51969417888A3E0195F33C2FF     Facts
# 24        002120F51969417888A3E0195F33C2FF     Facts
# 25        002120F51969417888A3E0195F33C2FF     Facts
# 27        002120F51969417888A3E0195F33C2FF   Periods
# 31        002B64F2FF6145AEAE261EAAFE7A75E9     Facts
# 32        002B64F2FF6145AEAE261EAAFE7A75E9     Facts
# 33        002B64F2FF6145AEAE261EAAFE7A75E9     Facts
# 35        002B64F2FF6145AEAE261EAAFE7A75E9   Markets
# 36        002B64F2FF6145AEAE261EAAFE7A75E9   Markets
# 42        002B64F2FF6145AEAE261EAAFE7A75E9  Products
# 45        00412EE4AE2C489C8E38A0251F0A2F5D     Facts
# 48        00412EE4AE2C489C8E38A0251F0A2F5D   Periods
# 55        004F0D504F9B46C18E053597C134ED3F  Products
# 56        0062505EDC2948F6AB1E9B21F8D1E8AF     Facts
# 60        0062505EDC2948F6AB1E9B21F8D1E8AF  Products
# 66        00644ACA9F0C439EB739323193742861  Products
# 76        006C4203F0534F369A5CAA00B998E3CF     Facts
# ...

# %%
def func():
    
    val_count['val_desc'] = va
